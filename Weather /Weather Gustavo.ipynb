# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
toronto_2015 = "Resources/toronto_climate_2015.csv"
toronto_2016 = "Resources/toronto_climate_2016.csv"
toronto_2017 = "Resources/toronto_climate_2017.csv"
toronto_2018 = "Resources/toronto_climate_2018.csv"
toronto_2019 = "Resources/toronto_climate_2019.csv"

# %%
vancouver_2015 = "Resources/vancouver_climate_2015.csv"
vancouver_2016 = "Resources/vancouver_climate_2016.csv"
vancouver_2017 = "Resources/vancouver_climate_2017.csv"
vancouver_2018 = "Resources/vancouver_climate_2018.csv"
vancouver_2019 = "Resources/vancouver_climate_2019.csv"

# %%
montreal_2015 = "Resources/montreal_climate_2015.csv"
montreal_2016 = "Resources/montreal_climate_2016.csv"
montreal_2017 = "Resources/montreal_climate_2017.csv"
montreal_2018 = "Resources/montreal_climate_2018.csv"
montreal_2019 = "Resources/montreal_climate_2019.csv"

# %%
halifax_2015 = "Resources/halifax_climate_2015.csv"
halifax_2016 = "Resources/halifax_climate_2016.csv"
halifax_2017 = "Resources/halifax_climate_2017.csv"
halifax_2018 = "Resources/halifax_climate_2018.csv"
halifax_2019 = "Resources/halifax_climate_2019.csv"

# %%
toronto_15_df = pd.read_csv(toronto_2015)
toronto_16_df = pd.read_csv(toronto_2016)
toronto_17_df = pd.read_csv(toronto_2017)
toronto_18_df = pd.read_csv(toronto_2018)
toronto_19_df = pd.read_csv(toronto_2019)

# %%
vancouver_15_df = pd.read_csv(vancouver_2015)
vancouver_16_df = pd.read_csv(vancouver_2016)
vancouver_17_df = pd.read_csv(vancouver_2017)
vancouver_18_df = pd.read_csv(vancouver_2018)
vancouver_19_df = pd.read_csv(vancouver_2019)

# %%
montreal_15_df = pd.read_csv(montreal_2015)
montreal_16_df = pd.read_csv(montreal_2016)
montreal_17_df = pd.read_csv(montreal_2017)
montreal_18_df = pd.read_csv(montreal_2018)
montreal_19_df = pd.read_csv(montreal_2019)

# %%
halifax_15_df = pd.read_csv(halifax_2015)
halifax_16_df = pd.read_csv(halifax_2016)
halifax_17_df = pd.read_csv(halifax_2017)
halifax_18_df = pd.read_csv(halifax_2018)
halifax_19_df = pd.read_csv(halifax_2019)

# %%
frames = [toronto_15_df, toronto_16_df, toronto_17_df, toronto_18_df, toronto_19_df, \
          vancouver_15_df, vancouver_16_df, vancouver_17_df, vancouver_18_df, vancouver_19_df, \
          montreal_15_df, montreal_16_df, montreal_17_df, montreal_18_df, montreal_19_df, \
          halifax_15_df, halifax_16_df, halifax_17_df, halifax_18_df, halifax_19_df]

# %%
weather_concat = pd.concat(frames)

# %%
weather_concat
# Out:
#      Longitude (x)  Latitude (y)               Station Name Climate ID  \
# 0           -79.40         43.67               TORONTO CITY    6158355
# 1           -79.40         43.67               TORONTO CITY    6158355
# 2           -79.40         43.67               TORONTO CITY    6158355
# 3           -79.40         43.67               TORONTO CITY    6158355
# 4           -79.40         43.67               TORONTO CITY    6158355
# ..             ...           ...                        ...        ...
# 360         -63.51         44.88  HALIFAX STANFIELD INT'L A    8202251
# 361         -63.51         44.88  HALIFAX STANFIELD INT'L A    8202251
# 362         -63.51         44.88  HALIFAX STANFIELD INT'L A    8202251
# 363         -63.51         44.88  HALIFAX STANFIELD INT'L A    8202251
# 364         -63.51         44.88  HALIFAX STANFIELD INT'L A    8202251
#
#       Date/Time  Year  Month  Day  Data Quality  Max Temp (°C)  ...  \
# 0    2015-01-01  2015      1    1           NaN           -0.9  ...
# 1    2015-01-02  2015      1    2           NaN           -0.5  ...
# 2    2015-01-03  2015      1    3           NaN            2.8  ...
# 3    2015-01-04  2015      1    4           NaN            5.1  ...
# 4    2015-01-05  2015      1    5           NaN           -4.6  ...
# ..          ...   ...    ...  ...           ...            ...  ...
# 360  2019-12-27  2019     12   27           NaN            3.3  ...
# 361  2019-12-28  2019     12   28           NaN            4.2  ...
# 362  2019-12-29  2019     12   29           NaN            0.3  ...
# 363  2019-12-30  2019     12   30           NaN           -1.2  ...
# 364  2019-12-31  2019     12   31           NaN            4.3  ...
#
#     Total Snow (cm)  Total Snow Flag Total Precip (mm)  Total Precip Flag  \
# 0               NaN                M               0.0                NaN
# 1               NaN                M               0.0                NaN
# 2               NaN                M              12.3                NaN
# 3               NaN                M              10.8                NaN
# 4               NaN                M               0.2                NaN
# ..              ...              ...               ...                ...
# 360             8.6              NaN               7.7                NaN
# 361             0.0                T               0.0                  T
# 362             0.0              NaN               0.0                NaN
# 363             0.0                T               0.0                  T
# 364             3.0              NaN              11.4                NaN
#
#     Snow on Grnd (cm)  Snow on Grnd Flag Dir of Max Gust (10s deg)  \
# 0                 NaN                NaN                       NaN
# 1                 NaN                NaN                       NaN
# 2                 NaN                NaN                       NaN
# 3                 NaN                NaN                       NaN
# 4                 NaN                NaN                       NaN
# ..                ...                ...                       ...
# 360               2.0                NaN                      24.0
# 361               3.0                NaN                      32.0
# 362               2.0                NaN                      33.0
# 363               1.0                NaN                       1.0
# 364               1.0                NaN                      12.0
#
#      Dir of Max Gust Flag Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                       M                    NaN                     M
# 1                       M                    NaN                     M
# 2                       M                    NaN                     M
# 3                       M                    NaN                     M
# 4                       M                    NaN                     M
# ..                    ...                    ...                   ...
# 360                   NaN                     41                   NaN
# 361                   NaN                     48                   NaN
# 362                   NaN                     50                   NaN
# 363                   NaN                     54                   NaN
# 364                   NaN                     72                   NaN
#
# [7304 rows x 31 columns]

# %%
weather_concat.columns
# Out:
# Index(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID',
#        'Date/Time', 'Year', 'Month', 'Day', 'Data Quality', 'Max Temp (°C)',
#        'Max Temp Flag', 'Min Temp (°C)', 'Min Temp Flag', 'Mean Temp (°C)',
#        'Mean Temp Flag', 'Heat Deg Days (°C)', 'Heat Deg Days Flag',
#        'Cool Deg Days (°C)', 'Cool Deg Days Flag', 'Total Rain (mm)',
#        'Total Rain Flag', 'Total Snow (cm)', 'Total Snow Flag',
#        'Total Precip (mm)', 'Total Precip Flag', 'Snow on Grnd (cm)',
#        'Snow on Grnd Flag', 'Dir of Max Gust (10s deg)',
#        'Dir of Max Gust Flag', 'Spd of Max Gust (km/h)',
#        'Spd of Max Gust Flag'],
#       dtype='object')

# %%
weather_cleaned = weather_concat[["Station Name","Month","Mean Temp (°C)","Total Precip (mm)"]]

# %%
weather_cleaned
# Out:
#                   Station Name  Month  Mean Temp (°C)  Total Precip (mm)
# 0                 TORONTO CITY      1            -3.9                0.0
# 1                 TORONTO CITY      1            -2.3                0.0
# 2                 TORONTO CITY      1            -0.4               12.3
# 3                 TORONTO CITY      1             0.2               10.8
# 4                 TORONTO CITY      1            -8.6                0.2
# ..                         ...    ...             ...                ...
# 360  HALIFAX STANFIELD INT'L A     12            -3.6                7.7
# 361  HALIFAX STANFIELD INT'L A     12             2.1                0.0
# 362  HALIFAX STANFIELD INT'L A     12            -2.7                0.0
# 363  HALIFAX STANFIELD INT'L A     12            -3.5                0.0
# 364  HALIFAX STANFIELD INT'L A     12             0.0               11.4
#
# [7304 rows x 4 columns]

# %%
weather_avg = weather_cleaned.groupby(by=["Station Name","Month"]).mean()

# %%
weather_avg_df = pd.DataFrame(weather_avg)
weather_avg_df
# Out:
#                                             Mean Temp (°C)  Total Precip (mm)
# Station Name                         Month
# HALIFAX STANFIELD INT'L A            1           -4.630519           4.859091
#                                      2           -4.571739           5.046099
#                                      3           -2.080392           4.532237
#                                      4            3.951007           4.987248
#                                      5           10.138562           3.143791
#                                      6           14.356757           4.299329
#                                      7           19.501935           2.980795
#                                      8           19.956863           2.268831
#                                      9           15.957823           3.372789
#                                      10           9.724026           5.244805
#                                      11           3.817123           5.503378
#                                      12          -1.850000           4.828387
# MONTREAL/PIERRE ELLIOTT TRUDEAU INTL 1           -8.492857           2.159211
#                                      2           -7.453957           2.436765
#                                      3           -2.409740           1.957143
#                                      4            5.461486           3.523129
#                                      5           14.478431           2.374172
#                                      6           18.536486           2.987075
#                                      7           22.428571           2.748052
#                                      8           21.515033           2.971242
#                                      9           17.703356           2.442282
#                                      10           9.772789           4.682877
#                                      11           1.469014           2.374468
#                                      12          -4.103268           2.575163
# TORONTO CITY                         1           -3.747368           1.871429
#                                      2           -3.007143           1.836134
#                                      3            0.783108           1.803704
#                                      4            7.133099           3.073239
#                                      5           14.731126           2.602703
#                                      6           19.192517           3.180272
#                                      7           22.832667           1.665541
#                                      8           22.175000           2.261644
#                                      9           19.284564           1.704082
#                                      10          11.718182           2.397403
#                                      11           4.779021           1.993662
#                                      12           0.396000           2.052667
# VANCOUVER INTL A                     1            4.509032           5.280519
#                                      2            4.247143           3.952857
#                                      3            7.115484           4.320000
#                                      4            9.857047           3.075676
#                                      5           14.152258           1.241830
#                                      6           16.414094           1.220270
#                                      7           18.712338           0.598693
#                                      8           18.562338           0.835065
#                                      9           14.870000           2.552000
#                                      10          10.211765           4.305844
#                                      11           6.933108           6.023490
#                                      12           3.772258           6.325161

# %%
weather_avg_df = weather_avg_df.reset_index()

# %%
weather_city = weather_avg_df.rename(columns={"Station Name":"City","Mean Temp (°C)":"Avg Temp (°C)","Total Precip (mm)":"Avg Precip (mm)"})

# %%
weather_city
# Out:
#                                     City  Month  Avg Temp (°C)  \
# 0              HALIFAX STANFIELD INT'L A      1      -4.630519
# 1              HALIFAX STANFIELD INT'L A      2      -4.571739
# 2              HALIFAX STANFIELD INT'L A      3      -2.080392
# 3              HALIFAX STANFIELD INT'L A      4       3.951007
# 4              HALIFAX STANFIELD INT'L A      5      10.138562
# 5              HALIFAX STANFIELD INT'L A      6      14.356757
# 6              HALIFAX STANFIELD INT'L A      7      19.501935
# 7              HALIFAX STANFIELD INT'L A      8      19.956863
# 8              HALIFAX STANFIELD INT'L A      9      15.957823
# 9              HALIFAX STANFIELD INT'L A     10       9.724026
# 10             HALIFAX STANFIELD INT'L A     11       3.817123
# 11             HALIFAX STANFIELD INT'L A     12      -1.850000
# 12  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      1      -8.492857
# 13  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      2      -7.453957
# 14  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      3      -2.409740
# 15  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      4       5.461486
# 16  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      5      14.478431
# 17  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      6      18.536486
# 18  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      7      22.428571
# 19  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      8      21.515033
# 20  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL      9      17.703356
# 21  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL     10       9.772789
# 22  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL     11       1.469014
# 23  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL     12      -4.103268
# 24                          TORONTO CITY      1      -3.747368
# 25                          TORONTO CITY      2      -3.007143
# 26                          TORONTO CITY      3       0.783108
# 27                          TORONTO CITY      4       7.133099
# 28                          TORONTO CITY      5      14.731126
# 29                          TORONTO CITY      6      19.192517
# 30                          TORONTO CITY      7      22.832667
# 31                          TORONTO CITY      8      22.175000
# 32                          TORONTO CITY      9      19.284564
# 33                          TORONTO CITY     10      11.718182
# 34                          TORONTO CITY     11       4.779021
# 35                          TORONTO CITY     12       0.396000
# 36                      VANCOUVER INTL A      1       4.509032
# 37                      VANCOUVER INTL A      2       4.247143
# 38                      VANCOUVER INTL A      3       7.115484
# 39                      VANCOUVER INTL A      4       9.857047
# 40                      VANCOUVER INTL A      5      14.152258
# 41                      VANCOUVER INTL A      6      16.414094
# 42                      VANCOUVER INTL A      7      18.712338
# 43                      VANCOUVER INTL A      8      18.562338
# 44                      VANCOUVER INTL A      9      14.870000
# 45                      VANCOUVER INTL A     10      10.211765
# 46                      VANCOUVER INTL A     11       6.933108
# 47                      VANCOUVER INTL A     12       3.772258
#
#     Avg Precip (mm)
# 0          4.859091
# 1          5.046099
# 2          4.532237
# 3          4.987248
# 4          3.143791
# 5          4.299329
# 6          2.980795
# 7          2.268831
# 8          3.372789
# 9          5.244805
# 10         5.503378
# 11         4.828387
# 12         2.159211
# 13         2.436765
# 14         1.957143
# 15         3.523129
# 16         2.374172
# 17         2.987075
# 18         2.748052
# 19         2.971242
# 20         2.442282
# 21         4.682877
# 22         2.374468
# 23         2.575163
# 24         1.871429
# 25         1.836134
# 26         1.803704
# 27         3.073239
# 28         2.602703
# 29         3.180272
# 30         1.665541
# 31         2.261644
# 32         1.704082
# 33         2.397403
# 34         1.993662
# 35         2.052667
# 36         5.280519
# 37         3.952857
# 38         4.320000
# 39         3.075676
# 40         1.241830
# 41         1.220270
# 42         0.598693
# 43         0.835065
# 44         2.552000
# 45         4.305844
# 46         6.023490
# 47         6.325161

# %%
weather_city = weather_city.replace({"HALIFAX STANFIELD INT'L A":"Halifax" , "MONTREAL/PIERRE ELLIOTT TRUDEAU INTL":"Montreal" , "TORONTO CITY":"Toronto" , "VANCOUVER INTL A":"Vancouver"})

# %%
weather_city
# Out:
#          City  Month  Mean Temp (°C)  Total Precip (mm)
# 0     Halifax      1       -4.630519           4.859091
# 1     Halifax      2       -4.571739           5.046099
# 2     Halifax      3       -2.080392           4.532237
# 3     Halifax      4        3.951007           4.987248
# 4     Halifax      5       10.138562           3.143791
# 5     Halifax      6       14.356757           4.299329
# 6     Halifax      7       19.501935           2.980795
# 7     Halifax      8       19.956863           2.268831
# 8     Halifax      9       15.957823           3.372789
# 9     Halifax     10        9.724026           5.244805
# 10    Halifax     11        3.817123           5.503378
# 11    Halifax     12       -1.850000           4.828387
# 12   Montreal      1       -8.492857           2.159211
# 13   Montreal      2       -7.453957           2.436765
# 14   Montreal      3       -2.409740           1.957143
# 15   Montreal      4        5.461486           3.523129
# 16   Montreal      5       14.478431           2.374172
# 17   Montreal      6       18.536486           2.987075
# 18   Montreal      7       22.428571           2.748052
# 19   Montreal      8       21.515033           2.971242
# 20   Montreal      9       17.703356           2.442282
# 21   Montreal     10        9.772789           4.682877
# 22   Montreal     11        1.469014           2.374468
# 23   Montreal     12       -4.103268           2.575163
# 24    Toronto      1       -3.747368           1.871429
# 25    Toronto      2       -3.007143           1.836134
# 26    Toronto      3        0.783108           1.803704
# 27    Toronto      4        7.133099           3.073239
# 28    Toronto      5       14.731126           2.602703
# 29    Toronto      6       19.192517           3.180272
# 30    Toronto      7       22.832667           1.665541
# 31    Toronto      8       22.175000           2.261644
# 32    Toronto      9       19.284564           1.704082
# 33    Toronto     10       11.718182           2.397403
# 34    Toronto     11        4.779021           1.993662
# 35    Toronto     12        0.396000           2.052667
# 36  Vancouver      1        4.509032           5.280519
# 37  Vancouver      2        4.247143           3.952857
# 38  Vancouver      3        7.115484           4.320000
# 39  Vancouver      4        9.857047           3.075676
# 40  Vancouver      5       14.152258           1.241830
# 41  Vancouver      6       16.414094           1.220270
# 42  Vancouver      7       18.712338           0.598693
# 43  Vancouver      8       18.562338           0.835065
# 44  Vancouver      9       14.870000           2.552000
# 45  Vancouver     10       10.211765           4.305844
# 46  Vancouver     11        6.933108           6.023490
# 47  Vancouver     12        3.772258           6.325161

# %%
# weather_city["Month"]

# %%
weather_city["Quarter"] = weather_city["Month"].replace({1:"Q1",2:"Q1",3:"Q1", \
                                         4:"Q2",5:"Q2",6:"Q2", \
                                         7:"Q3",8:"Q3",9:"Q3", \
                                         10:"Q4",11:"Q4",12:"Q4"})

# %%
weather_city_df = weather_city[["City","Quarter","Mean Temp (°C)","Total Precip (mm)"]]

# %%
weather_city_df
# Out:
#          City Quarter  Mean Temp (°C)  Total Precip (mm)
# 0     Halifax      Q1       -4.630519           4.859091
# 1     Halifax      Q1       -4.571739           5.046099
# 2     Halifax      Q1       -2.080392           4.532237
# 3     Halifax      Q2        3.951007           4.987248
# 4     Halifax      Q2       10.138562           3.143791
# 5     Halifax      Q2       14.356757           4.299329
# 6     Halifax      Q3       19.501935           2.980795
# 7     Halifax      Q3       19.956863           2.268831
# 8     Halifax      Q3       15.957823           3.372789
# 9     Halifax      Q4        9.724026           5.244805
# 10    Halifax      Q4        3.817123           5.503378
# 11    Halifax      Q4       -1.850000           4.828387
# 12   Montreal      Q1       -8.492857           2.159211
# 13   Montreal      Q1       -7.453957           2.436765
# 14   Montreal      Q1       -2.409740           1.957143
# 15   Montreal      Q2        5.461486           3.523129
# 16   Montreal      Q2       14.478431           2.374172
# 17   Montreal      Q2       18.536486           2.987075
# 18   Montreal      Q3       22.428571           2.748052
# 19   Montreal      Q3       21.515033           2.971242
# 20   Montreal      Q3       17.703356           2.442282
# 21   Montreal      Q4        9.772789           4.682877
# 22   Montreal      Q4        1.469014           2.374468
# 23   Montreal      Q4       -4.103268           2.575163
# 24    Toronto      Q1       -3.747368           1.871429
# 25    Toronto      Q1       -3.007143           1.836134
# 26    Toronto      Q1        0.783108           1.803704
# 27    Toronto      Q2        7.133099           3.073239
# 28    Toronto      Q2       14.731126           2.602703
# 29    Toronto      Q2       19.192517           3.180272
# 30    Toronto      Q3       22.832667           1.665541
# 31    Toronto      Q3       22.175000           2.261644
# 32    Toronto      Q3       19.284564           1.704082
# 33    Toronto      Q4       11.718182           2.397403
# 34    Toronto      Q4        4.779021           1.993662
# 35    Toronto      Q4        0.396000           2.052667
# 36  Vancouver      Q1        4.509032           5.280519
# 37  Vancouver      Q1        4.247143           3.952857
# 38  Vancouver      Q1        7.115484           4.320000
# 39  Vancouver      Q2        9.857047           3.075676
# 40  Vancouver      Q2       14.152258           1.241830
# 41  Vancouver      Q2       16.414094           1.220270
# 42  Vancouver      Q3       18.712338           0.598693
# 43  Vancouver      Q3       18.562338           0.835065
# 44  Vancouver      Q3       14.870000           2.552000
# 45  Vancouver      Q4       10.211765           4.305844
# 46  Vancouver      Q4        6.933108           6.023490
# 47  Vancouver      Q4        3.772258           6.325161

# %%
weather_city_quarterly = weather_city_df.groupby(by=["City","Quarter"]).mean()

# %%
weather_city_quarterly
# Out:
#                    Mean Temp (°C)  Total Precip (mm)
# City      Quarter
# Halifax   Q1            -3.760884           4.812476
#           Q2             9.482109           4.143456
#           Q3            18.472207           2.874138
#           Q4             3.897050           5.192190
# Montreal  Q1            -6.118851           2.184373
#           Q2            12.825468           2.961459
#           Q3            20.548987           2.720525
#           Q4             2.379512           3.210836
# Toronto   Q1            -1.990468           1.837089
#           Q2            13.685580           2.952071
#           Q3            21.430743           1.877089
#           Q4             5.631068           2.147910
# Vancouver Q1             5.290553           4.517792
#           Q2            13.474466           1.845925
#           Q3            17.381558           1.328586
#           Q4             6.972377           5.551498

# %%
weather_city_quarterly = weather_city_quarterly.reset_index()

# %%
weather_city_quarterly.round(decimals=2)
# Out:
#          City Quarter  Mean Temp (°C)  Total Precip (mm)
# 0     Halifax      Q1           -3.76               4.81
# 1     Halifax      Q2            9.48               4.14
# 2     Halifax      Q3           18.47               2.87
# 3     Halifax      Q4            3.90               5.19
# 4    Montreal      Q1           -6.12               2.18
# 5    Montreal      Q2           12.83               2.96
# 6    Montreal      Q3           20.55               2.72
# 7    Montreal      Q4            2.38               3.21
# 8     Toronto      Q1           -1.99               1.84
# 9     Toronto      Q2           13.69               2.95
# 10    Toronto      Q3           21.43               1.88
# 11    Toronto      Q4            5.63               2.15
# 12  Vancouver      Q1            5.29               4.52
# 13  Vancouver      Q2           13.47               1.85
# 14  Vancouver      Q3           17.38               1.33
# 15  Vancouver      Q4            6.97               5.55

# %%
weather_city_quarterly
# Out:
#          City Quarter  Mean Temp (°C)  Total Precip (mm)
# 0     Halifax      Q1           -3.76               4.81
# 1     Halifax      Q2            9.48               4.14
# 2     Halifax      Q3           18.47               2.87
# 3     Halifax      Q4            3.90               5.19
# 4    Montreal      Q1           -6.12               2.18
# 5    Montreal      Q2           12.83               2.96
# 6    Montreal      Q3           20.55               2.72
# 7    Montreal      Q4            2.38               3.21
# 8     Toronto      Q1           -1.99               1.84
# 9     Toronto      Q2           13.69               2.95
# 10    Toronto      Q3           21.43               1.88
# 11    Toronto      Q4            5.63               2.15
# 12  Vancouver      Q1            5.29               4.52
# 13  Vancouver      Q2           13.47               1.85
# 14  Vancouver      Q3           17.38               1.33
# 15  Vancouver      Q4            6.97               5.55

# %%
cities = ["Halifax","Montreal","Toronto","Vancouver"]

# %%
temperature = []
precipitation = []

# %%
for city in cities:
    temp = weather_city_quarterly.loc[weather_city_quarterly["City"] == city, ["City","Quarter","Mean Temp (°C)"]]
    precip = weather_city_quarterly.loc[weather_city_quarterly["City"] == city, ["City","Quarter","Total Precip (mm)"]]
    temperature.append(temp)
    precipitation.append(precip)

# %%
temperature
# Out:
# [      City Quarter  Mean Temp (°C)
#  0  Halifax      Q1           -3.76
#  1  Halifax      Q2            9.48
#  2  Halifax      Q3           18.47
#  3  Halifax      Q4            3.90,
#         City Quarter  Mean Temp (°C)
#  4  Montreal      Q1           -6.12
#  5  Montreal      Q2           12.83
#  6  Montreal      Q3           20.55
#  7  Montreal      Q4            2.38,
#         City Quarter  Mean Temp (°C)
#  8   Toronto      Q1           -1.99
#  9   Toronto      Q2           13.69
#  10  Toronto      Q3           21.43
#  11  Toronto      Q4            5.63,
#           City Quarter  Mean Temp (°C)
#  12  Vancouver      Q1            5.29
#  13  Vancouver      Q2           13.47
#  14  Vancouver      Q3           17.38
#  15  Vancouver      Q4            6.97]

# %%
plt.plot(temperature[0]["Quarter"], temperature[0]["Mean Temp (°C)"])
plt.plot(temperature[1]["Quarter"], temperature[1]["Mean Temp (°C)"])
plt.plot(temperature[2]["Quarter"], temperature[2]["Mean Temp (°C)"])
plt.plot(temperature[3]["Quarter"], temperature[3]["Mean Temp (°C)"])

plt.title("Average temperature per city (2015 to 2019) - Quarterly")
plt.xticks(weather_city_quarterly["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
# plt.ylim(155, 205, 10)
plt.ylabel("Temperature (C)")
plt.legend(cities)
plt.grid()

plt.show()

# %%
precipitation
# Out:
# [      City Quarter  Total Precip (mm)
#  0  Halifax      Q1               4.81
#  1  Halifax      Q2               4.14
#  2  Halifax      Q3               2.87
#  3  Halifax      Q4               5.19,
#         City Quarter  Total Precip (mm)
#  4  Montreal      Q1               2.18
#  5  Montreal      Q2               2.96
#  6  Montreal      Q3               2.72
#  7  Montreal      Q4               3.21,
#         City Quarter  Total Precip (mm)
#  8   Toronto      Q1               1.84
#  9   Toronto      Q2               2.95
#  10  Toronto      Q3               1.88
#  11  Toronto      Q4               2.15,
#           City Quarter  Total Precip (mm)
#  12  Vancouver      Q1               4.52
#  13  Vancouver      Q2               1.85
#  14  Vancouver      Q3               1.33
#  15  Vancouver      Q4               5.55]

# %%
plt.bar(precipitation[0]["Quarter"], precipitation[0]["Total Precip (mm)"])

plt.title("Average precipitation per city (2015 to 2019) - Quarterly")
plt.xticks(weather_city_quarterly["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
# plt.ylim(155, 205, 10)
plt.ylabel("Precipitation (mm)")
plt.legend(cities)
plt.grid()

plt.show()

# %%
plt.bar(precipitation[1]["Quarter"], precipitation[1]["Total Precip (mm)"], color="orange")

plt.title("Average precipitation for Montreal (2015 to 2019) - Quarterly")
plt.xticks(weather_city_quarterly["Quarter"], ["Jan-Feb-Mar","Apr-May-Jun","Jul-Aug-Sep","Oct-Nov-Dec"], rotation=15)
# plt.ylim(155, 205, 10)
plt.ylabel("Precipitation (mm)")
# plt.legend(cities[1])
plt.grid()

plt.show()

# %%
x_values = weather_city_quarterly["Quarter"]

# %%
y_values = weather_city_quarterly["Mean Temp (°C)"]

# %%
plt.plot(x_values, y_values)

# %%
# weather_city_quarterly.replace({"Q1":"Jan-Feb-Mar", "Q2":"Apr-May-Jun", "Q3":"Jul-Aug-Sep", "Q4":"Oct-Nov-Dec"})
